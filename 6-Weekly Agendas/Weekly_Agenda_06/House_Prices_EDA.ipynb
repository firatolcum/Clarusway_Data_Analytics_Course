# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("House Prices .csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.select_dtypes(include="O").columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
for i in df.select_dtypes(include="O").columns:
    print(i)
    print(df[i].unique())
    print("-" * 100)
# Out:
# MSZoning
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# ----------------------------------------------------------------------------------------------------
# Street
# ['Pave' 'Grvl']
# ----------------------------------------------------------------------------------------------------
# Alley
# [nan 'Grvl' 'Pave']
# ----------------------------------------------------------------------------------------------------
# LotShape
# ['Reg' 'IR1' 'IR2' 'IR3']
# ----------------------------------------------------------------------------------------------------
# LandContour
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ----------------------------------------------------------------------------------------------------
# Utilities
# ['AllPub' 'NoSeWa']
# ----------------------------------------------------------------------------------------------------
# LotConfig
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ----------------------------------------------------------------------------------------------------
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.drop(columns="Id", inplace= True)

# %%
df.duplicated().value_counts()
# Out:
# False    1460
# dtype: int64

# %%
df.fillna("Unknown", inplace=True)

# %%
df.describe().T
# Out:
#                 count           mean           std      min        25%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# ...

# %%
df.corr()
# Out:
#                MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  \
# MSSubClass       1.000000 -0.139781     0.032628    -0.059316   0.027850
# LotArea         -0.139781  1.000000     0.105806    -0.005636   0.014228
# OverallQual      0.032628  0.105806     1.000000    -0.091932   0.572323
# OverallCond     -0.059316 -0.005636    -0.091932     1.000000  -0.375983
# YearBuilt        0.027850  0.014228     0.572323    -0.375983   1.000000
# YearRemodAdd     0.040581  0.013788     0.550684     0.073741   0.592855
# BsmtFinSF1      -0.069836  0.214103     0.239666    -0.046231   0.249503
# BsmtFinSF2      -0.065649  0.111170    -0.059119     0.040229  -0.049107
# BsmtUnfSF       -0.140759 -0.002618     0.308159    -0.136841   0.149040
# TotalBsmtSF     -0.238518  0.260833     0.537808    -0.171098   0.391452
# 1stFlrSF        -0.251758  0.299475     0.476224    -0.144203   0.281986
# 2ndFlrSF         0.307886  0.050986     0.295493     0.028942   0.010308
# ...

# %% [markdown]
# #####  OverallQual vs SalePrice
# OverallQual: Rates the overall material and finish of the house

# %%
df["OverallQual"].corr(df["SalePrice"]) *100
# Out:
# 79.0981600583805

# %%
sns.lineplot(data=df, x="OverallQual", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.scatterplot(data=df, x="OverallQual", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.barplot(data=df, x="OverallQual", y="SalePrice");

# %% [markdown]
# ##### TotalBsmtSF vs SalePrice
# TotalBsmtSF: Total square feet of basement area

# %%
df["TotalBsmtSF"].corr(df["SalePrice"]) * 100
# Out:
# 61.35805515591956

# %%
sns.scatterplot(data=df, x="TotalBsmtSF", y="SalePrice");

# %% [markdown]
# ##### 1stFlrSF vs SalePrice
# 1stFlrSF: First Floor square feet

# %%
df["1stFlrSF"].corr(df["SalePrice"]) * 100
# Out:
# 60.585218469191474

# %%
sns.scatterplot(data=df, x="1stFlrSF", y="SalePrice");

# %% [markdown]
# ##### GrLivArea vs SalePrice
# GrLivArea: Above grade (ground) living area square feet

# %%
df["GrLivArea"].corr(df["SalePrice"]) * 100
# Out:
# 70.86244776126523

# %%
sns.scatterplot(data=df, x="GrLivArea", y="SalePrice");

# %% [markdown]
# ##### FullBath vs SalePrice
# FullBath: Full bathrooms above grade

# %%
sns.lineplot(data=df, x="FullBath", y="SalePrice");

# %%
sns.scatterplot(data=df, x="FullBath", y="SalePrice");

# %% [markdown]
# ##### TotRmsAbvGrd vs SalePrice
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)

# %%
df["TotRmsAbvGrd"].corr(df["SalePrice"]) * 100
# Out:
# 53.37231555820283

# %%
sns.lineplot(data=df, x="TotRmsAbvGrd", y="SalePrice");

# %%
sns.scatterplot(data=df, x="TotRmsAbvGrd", y="SalePrice");

# %% [markdown]
# ##### GarageCars vs SalePrice
# GarageCars: Size of garage in car capacity

# %%
df["GarageCars"].corr(df["SalePrice"]) * 100
# Out:
# 64.04091972583522

# %%
sns.lineplot(data=df, x="GarageCars", y="SalePrice");

# %%
sns.scatterplot(data=df, x="GarageCars", y="SalePrice");

# %% [markdown]
# ##### GarageArea vs SalePrice
# GarageArea: Size of garage in square feet

# %%
df["GarageArea"].corr(df["SalePrice"]) * 100
# Out:
# 62.34314389183619

# %%
sns.scatterplot(data=df, x="GarageArea", y="SalePrice");

# %% [markdown]
# ##### MSSubClass  Research
# MSSubClass: Identifies the type of dwelling involved in the sale.

# %%
ax = sns.countplot(data=df, x='MSSubClass');
for container in ax.containers:
    ax.bar_label(container)
    
#  20	1-STORY 1946 & NEWER ALL STYLES
#  60	2-STORY 1946 & NEWER
#  50	1-1/2 STORY FINISHED ALL AGES

# %% [markdown]
# ##### MSZoning Research
# MSZoning: Identifies the general zoning classification of the sale.

# %%
ax = sns.countplot(data=df, x='MSZoning');
for container in ax.containers:
    ax.bar_label(container)
    
plt.tight_layout()    

#  RL	Residential Low Density
#  RM	Residential Medium Density
#  RH	Residential High Density
#  FV	Floating Village Residential
#  C	Commercial

# %% [markdown]
# ##### Street Research
# Street: Type of road access to property

# %%
ax = sns.countplot(data=df, x='Street');
for container in ax.containers:
    ax.bar_label(container)
    
#  Grvl 	Grave
#  Pave 	Paved

# %% [markdown]
# ##### Alley Research
# Alley: Type of alley access to property

# %%
ax = sns.countplot(data=df, x='Alley');
for container in ax.containers:
    ax.bar_label(container)

#  Grvl 	Gravel
#  Pave 	Paved

# %% [markdown]
# ##### LotShape Research
# LotShape: General shape of property

# %%
ax = sns.countplot(data=df, x='LotShape');
for container in ax.containers:
    ax.bar_label(container)
    
#  Reg	Regular
#  IR1	Slightly irregular
#  IR2	Moderately Irregular
#  IR3	Irregular

# %% [markdown]
# ##### LandContour Researh
# LandContour: Flatness of the property

# %%
ax = sns.countplot(data=df, x='LandContour');
for container in ax.containers:
    ax.bar_label(container)
    
# Lvl	Near Flat/Level
# Bnk	Banked - Quick and significant rise from street grade to building
# HLS	Hillside - Significant slope from side to side
# Low	Depression

# %% [markdown]
# ##### Utilities Research
# Utilities: Type of utilities available

# %%
ax = sns.countplot(data=df, x='Utilities');
for container in ax.containers:
    ax.bar_label(container)
    
#  AllPub	All public Utilities (E,G,W,& S)
#   NoSeWa	Electricity and Gas Only

# %% [markdown]
# ##### LotConfig Research
# LotConfig: Lot configuration

# %%
ax = sns.countplot(data=df, x='LotConfig');
for container in ax.containers:
    ax.bar_label(container)
    
    
# Inside	Inside lot
#  Corner	Corner lot
#  CulDSac	Cul-de-sac
#  FR2	Frontage on 2 sides of property
#  FR3	Frontage on 3 sides of property

# %% [markdown]
# ##### LandSlope Research
# LandSlope: Slope of property

# %%
ax = sns.countplot(data=df, x='LandSlope');
for container in ax.containers:
    ax.bar_label(container)
    
# Gtl	Gentle slope
# Mod	Moderate Slope
# Sev	Severe Slope

# %% [markdown]
# ##### Neighborhood Research
# Neighborhood: Physical locations within Ames city limits

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(data=df, x='Neighborhood');
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=60);

#  Names	North Ames
#  CollgCr	College Creek
#  OldTown	Old Town
#  Edwards	Edwards

# %% [markdown]
# ##### Condition1 Research
# Condition1: Proximity to various conditions

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(data=df, x='Condition1');
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=60);

#  Norm 	Normal
#  Feedr	Adjacent to feeder street
#  Artery	Adjacent to arterial street

# %% [markdown]
# ##### Condition2 Research
# Condition2: Proximity to various conditions (if more than one is present)

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(data=df, x='Condition2');
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=60);

# %% [markdown]
# ##### BldgType Researh
# BldgType: Type of dwelling

# %%
ax = sns.countplot(data=df, x='BldgType');
for container in ax.containers:
    ax.bar_label(container)
    
#  1Fam 	Single-family Detached
#  TwnhsE	Townhouse End Unit
#  Duplx	Duplex

# %% [markdown]
# ##### HouseStyle
# HouseStyle: Style of dwelling

# %%
ax = sns.countplot(data=df, x='HouseStyle');
for container in ax.containers:
    ax.bar_label(container)
    
#  1Story	One story
#  2Story	Two story
#  1.5Fin	One and one-half story: 2nd level finished

# %% [markdown]
# ##### OverallQual  Research
# OverallQual: Rates the overall material and finish of the house

# %%
ax = sns.countplot(data=df, x='OverallQual');
for container in ax.containers:
    ax.bar_label(container)
    
#  1	Very Poor
#  10	Very Excellent

# %% [markdown]
# ##### OverallCond Research
# OverallCond: Rates the overall condition of the house

# %%
ax = sns.countplot(data=df, x='OverallCond');
for container in ax.containers:
    ax.bar_label(container)

# %%
sns.barplot(data=df, x="OverallCond", y="SalePrice");

# %% [markdown]
# ##### YearBuilt
# YearBuilt: Original construction date

# %%
sns.scatterplot(data=df, x="YearBuilt", y="SalePrice")
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %% [markdown]
# ##### RoofStyle Search
# RoofStyle: Type of roof

# %%
ax = sns.countplot(data=df, x='RoofStyle');
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ##### RoofMatl Search
# RoofMatl: Roof material

# %%
ax = sns.countplot(data=df, x='RoofMatl');
for container in ax.containers:
    ax.bar_label(container)
plt.xticks(rotation=45);

#  CompShg	Standard (Composite) Shingle

# %% [markdown]
# ##### Exterior1st Research
# Exterior1st: Exterior covering on house

# %%
ax = sns.countplot(data=df, x='Exterior1st')
for container in ax.containers:
    ax.bar_label(container)
    
plt.xticks(rotation=70);

#  VinylSd	Vinyl Siding
#  HdBoard	Hard Board
#  MetalSd	Metal Siding
#  Wd Sdng	Wood Siding

# %% [markdown]
# ##### Exterior2nd Research
# Exterior2nd: Exterior covering on house (if more than one material)

# %%
ax = sns.countplot(data=df, x='Exterior2nd')
for container in ax.containers:
    ax.bar_label(container)
    
plt.xticks(rotation=70);

# %% [markdown]
# ##### MasVnrType Research
# MasVnrType: Masonry veneer type

# %%
ax = sns.countplot(data=df, x='MasVnrType')
for container in ax.containers:
    ax.bar_label(container)
    
plt.xticks(rotation=45);

#  BrkFace	Brick Face
#  BrkCmn	Brick Common
