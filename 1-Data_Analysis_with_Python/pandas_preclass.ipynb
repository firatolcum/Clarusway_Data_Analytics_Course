# %%
import pandas as pd

# %%
serr = pd.Series([11, 21, 13, 41, 15, 61])
serr
# Out:
# 0    11
# 1    21
# 2    13
# 3    41
# 4    15
# 5    61
# dtype: int64

# %%
d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d, index=['a', 'b', 'c'])
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser = pd.Series(data=d, index=[1,2,3,4])
ser
# Out:
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# dtype: float64

# %%
series = pd.Series(("Nik", "P","nik@email.com",175))
series
# Out:
# 0              Nik
# 1                P
# 2    nik@email.com
# 3              175
# dtype: object

# %%
ser = pd.Series(list("Fırat"))
ser
# Out:
# 0    F
# 1    ı
# 2    r
# 3    a
# 4    t
# dtype: object

# %%
ser.sort_index(ascending=False)
# Out:
# 4    t
# 3    a
# 2    r
# 1    ı
# 0    F
# dtype: object

# %%
ser.sort_index()
# Out:
# 0    F
# 1    ı
# 2    r
# 3    a
# 4    t
# dtype: object

# %%
ser.sort_values() # default ascending=True and sort by ascii code
# Out:
# 0    F
# 3    a
# 2    r
# 4    t
# 1    ı
# dtype: object

# %%
ser.sort_values()
# Out:
# 0    F
# 3    a
# 2    r
# 4    t
# 1    ı
# dtype: object

# %%
import pandas as pd
import numpy as np
s = pd.Series([np.nan, 1, 3, 10, 5])
s.sort_values()
# Out:
# 1     1.0
# 2     3.0
# 4     5.0
# 3    10.0
# 0     NaN
# dtype: float64

# %%
ser
# Out:
# 0    F
# 1    ı
# 2    r
# 3    a
# 4    t
# dtype: object

# %%
ser = pd.Series(list("Fırat"))
ser.isin(["F"])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
ser.isin({"F"})
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
ser
# Out:
# 0    F
# 1    ı
# 2    r
# 3    a
# 4    t
# dtype: object

# %%
ser = pd.Series([2,4,6,8,10])
ser.keys()
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser.keys()
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
ser.values
# Out:
# array([ 2,  4,  6,  8, 10], dtype=int64)

# %%
ser = pd.Series(list("Fırat"))
ser.values
# Out:
# array(['F', 'ı', 'r', 'a', 't'], dtype=object)

# %%
pd.Series(list("Fırat")).values
# Out:
# array(['F', 'ı', 'r', 'a', 't'], dtype=object)

# %%
pd.Series(list('aabc')).astype('category').values
# Out:
# ['a', 'a', 'b', 'c']
# Categories (3, object): ['a', 'b', 'c']

# %%
pd.Series(list("Fırat")).items
# Out:
# <bound method Series.items of 0    F
# 1    ı
# 2    r
# 3    a
# 4    t
# dtype: object>

# %%
ser
# Out:
# 0    F
# 1    ı
# 2    r
# 3    a
# 4    t
# dtype: object

# %%
ser = pd.Series(list("Fırat"))
list(ser.items())
# Out:
# [(0, 'F'), (1, 'ı'), (2, 'r'), (3, 'a'), (4, 't')]

# %%
s = pd.Series(['A', 'B', 'C'])
for index, value in s.items():
    print(f"Index : {index}, Value : {value}")
# Out:
# Index : 0, Value : A
# Index : 1, Value : B
# Index : 2, Value : C

# %%
pd.read_csv("my_file.csv")
# Out:
#      name  lastname   age       city
# 0   fırat     olçum    31     Ankara
# 1  serhat     olçum    30     Ankara
# 2  ferhat     olçum    36   İstanbul
# 3     ali    cengiz    45    Hakkari
# 4  mehmet      mert    37        Muş
# 5   melih       Mut    56    Malatya

# %%
df = pd.read_csv("my_file.csv")
df.head()
# Out:
#      name  lastname   age       city
# 0   fırat     olçum    31     Ankara
# 1  serhat     olçum    30     Ankara
# 2  ferhat     olçum    36   İstanbul
# 3     ali    cengiz    45    Hakkari
# 4  mehmet      mert    37        Muş

# %%
df = pd.DataFrame(np.arange(1, 24, 2).reshape(3,4),
                  columns=["var1", "var2", "var3", "var4"])
df
# Out:
#    var1  var2  var3  var4
# 0     1     3     5     7
# 1     9    11    13    15
# 2    17    19    21    23

# %%
df = pd.DataFrame(np.arange(1, 24, 2).reshape(3,4),
                  columns=["var1", "var2", "var3", "var4"])
df.tail(1)
# Out:
#    var1  var2  var3  var4
# 2    17    19    21    23

# %%
df = pd.DataFrame(np.arange(1, 24, 2).reshape(3,4),
                  columns=["var1", "var2", "var3", "var4"])
df.sample(n=2)
# Out:
#    var1  var2  var3  var4
# 0     1     3     5     7
# 2    17    19    21    23

# %%
df = pd.read_csv("my_file.csv")
df
# Out:
#      name  lastname   age       city
# 0   fırat     olçum    31     Ankara
# 1  serhat     olçum    30     Ankara
# 2  ferhat     olçum    36   İstanbul
# 3     ali    cengiz    45    Hakkari
# 4  mehmet      mert    37        Muş
# 5   melih       Mut    56    Malatya

# %%
df.shape
# Out:
# (6, 4)

# %%
dataframe1 = pd.DataFrame ([("Nik", "P", "30", "nik@email.com", 175),
                            ("Evan", "D", 31, "evan@email.com", 170)],
                           columns=["First Name", "Last Initial", "Age", "Email", "Weight"])
dataframe1
# Out:
#   First Name Last Initial Age           Email  Weight
# 0        Nik            P  30   nik@email.com     175
# 1       Evan            D  31  evan@email.com     170

# %%
dataframe2 = pd.DataFrame ({"First Name" : ["Nik", "Evan"],
                            "Last Initial" : ["P", "D"],
                            "Age" : [30, 31],
                            "Height" : ["nik@email.com", "evan@email.com"],
                            "Weight" : [175, 170]})
dataframe2
# Out:
#   First Name Last Initial  Age          Height  Weight
# 0        Nik            P   30   nik@email.com     175
# 1       Evan            D   31  evan@email.com     170

# %%
df = pd.read_csv("woman-stem.csv")
df
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv")
df
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.shape
# Out:
# (76, 9)

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.tail()
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
np.random.seed(101)
df = pd.DataFrame(np.random.randint(9, size=(5, 4)),
                  index="A B C D E".split(),
                  columns="W X Y Z".split())
df
# Out:
#    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0

# %%
df.reset_index()
# Out:
#   index  W  X  Y  Z
# 0     A  1  6  7  8
# 1     B  4  8  5  0
# 2     C  5  8  1  3
# 3     D  8  3  3  2
# 4     E  8  3  7  0

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.shape
# Out:
# (5, 4)

# %%
df.size
# Out:
# 20

# %%
df.ndim
# Out:
# 2

# %%
df
# Out:
#    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0

# %%
df.reset_index()
# Out:
#   index  W  X  Y  Z
# 0     A  1  6  7  8
# 1     B  4  8  5  0
# 2     C  5  8  1  3
# 3     D  8  3  3  2
# 4     E  8  3  7  0

# %%
newindex = "CA NY WY OR CO".split()
newindex
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df["newidx"] = newindex
df
# Out:
#    W  X  Y  Z newidx
# A  1  6  7  8     CA
# B  4  8  5  0     NY
# C  5  8  1  3     WY
# D  8  3  3  2     OR
# E  8  3  7  0     CO

# %%
df.set_index("newidx")
# Out:
#         W  X  Y  Z
# newidx
# CA      1  6  7  8
# NY      4  8  5  0
# WY      5  8  1  3
# OR      8  3  3  2
# CO      8  3  7  0

# %%
df.set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Samsung\Desktop\Clarusway\Data Science Module 1\DawPy\pandas_preclass.ipynb Cell 53' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Samsung/Desktop/Clarusway/Data%20Science%20Module%201/DawPy/pandas_preclass.ipynb#ch0000052?line=0'>1</a> df.set_index()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/Samsung/anaconda3/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/Samsung/anaconda3/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
# ...

# %%
df = pd.DataFrame({'month': [1, 4, 7, 10], 
                   'year': [2012, 2014, 2013, 2014],
                   'sale': [55, 40, 84, 31]})

print(df)
df.set_index('month')
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31
#        year  sale
# month
# 1      2012    55
# 4      2014    40
# 7      2013    84
# 10     2014    31

# %%
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df["month"]
# Out:
# 0     1
# 1     4
# 2     7
# 3    10
# Name: month, dtype: int64

# %%
df.month
# Out:
# 0     1
# 1     4
# 2     7
# 3    10
# Name: month, dtype: int64

# %%
df
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df.iloc[1, 0]
# Out:
# 4

# %%
df.iloc[1, 1]
# Out:
# 2014

# %%
df.loc[0, "month"]
# Out:
# 1

# %%
df.loc[1, "year"]
# Out:
# 2014

# %%
df = pd.DataFrame([[1, 2], [4, 5], [7, 8]],
                index=['cobra', 'viper', 'sidewinder'],
                columns=['max_speed', 'shield'])
df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
df.loc["viper", "max_speed"]
# Out:
# 4

# %%
df
# Out:
#             max_speed  shield
# cobra               1       2
# viper               4       5
# sidewinder          7       8

# %%
df[df.max_speed < 7]
# Out:
#        max_speed  shield
# cobra          1       2
# viper          4       5

# %%
df[df["max_speed"] < 7]
# Out:
#        max_speed  shield
# cobra          1       2
# viper          4       5

# %%
df = pd.read_csv("woman-stem.csv")
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.set_index("Major_code")
# Out:
#             Rank                                          Major  \
# Major_code
# 2419           1                          PETROLEUM ENGINEERING
# 2416           2                 MINING AND MINERAL ENGINEERING
# 2415           3                      METALLURGICAL ENGINEERING
# 2417           4      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 2418           5                            NUCLEAR ENGINEERING
# ...          ...                                            ...
# 3604          72                                        ECOLOGY
# 6109          73                  TREATMENT THERAPY PROFESSIONS
# 6100          74            GENERAL MEDICAL AND HEALTH SERVICES
# 6102          75  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 3609          76                                        ZOOLOGY
#
#                     Major_category  Total    Men  Women  ShareWomen  Median
# Major_code
# 2419                   Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df.Major
# Out:
# 0                             PETROLEUM ENGINEERING
# 1                    MINING AND MINERAL ENGINEERING
# 2                         METALLURGICAL ENGINEERING
# 3         NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               NUCLEAR ENGINEERING
#                           ...
# 71                                          ECOLOGY
# 72                    TREATMENT THERAPY PROFESSIONS
# 73              GENERAL MEDICAL AND HEALTH SERVICES
# 74    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df["Major"]
# Out:
# 0                             PETROLEUM ENGINEERING
# 1                    MINING AND MINERAL ENGINEERING
# 2                         METALLURGICAL ENGINEERING
# 3         NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               NUCLEAR ENGINEERING
#                           ...
# 71                                          ECOLOGY
# 72                    TREATMENT THERAPY PROFESSIONS
# 73              GENERAL MEDICAL AND HEALTH SERVICES
# 74    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.loc[2]
# Out:
# Rank                                      3
# Major_code                             2415
# Major             METALLURGICAL ENGINEERING
# Major_category                  Engineering
# Total                                   856
# Men                                     725
# Women                                   131
# ShareWomen                         0.153037
# Median                                73000
# Name: 2, dtype: object

# %%
df.loc[2, "Major"]
# Out:
# 'METALLURGICAL ENGINEERING'

# %%
df.head(2)
# Out:
#    Rank  Major_code                           Major Major_category  Total  \
# 0     1        2419           PETROLEUM ENGINEERING    Engineering   2339
# 1     2        2416  MINING AND MINERAL ENGINEERING    Engineering    756
#
#     Men  Women  ShareWomen  Median
# 0  2057    282    0.120564  110000
# 1   679     77    0.101852   75000

# %%
df.iloc[0]
# Out:
# Rank                                  1
# Major_code                         2419
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 0, dtype: object

# %%
df.loc[0, "Major"]
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0,1]
# Out:
# 2419

# %%
df.iloc[0, 2]
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0:5, 2:4]
# Out:
#                                        Major Major_category
# 0                      PETROLEUM ENGINEERING    Engineering
# 1             MINING AND MINERAL ENGINEERING    Engineering
# 2                  METALLURGICAL ENGINEERING    Engineering
# 3  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4                        NUCLEAR ENGINEERING    Engineering

# %%
df.tail()
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
df.iloc[-1, 1:3]
# Out:
# Major_code       3609
# Major         ZOOLOGY
# Name: 75, dtype: object

# %%
df.iloc[:5, :3]
# Out:
#    Rank  Major_code                                      Major
# 0     1        2419                      PETROLEUM ENGINEERING
# 1     2        2416             MINING AND MINERAL ENGINEERING
# 2     3        2415                  METALLURGICAL ENGINEERING
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4     5        2418                        NUCLEAR ENGINEERING

# %%
df["Major"] == "ECOLOGY"
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 71     True
# 72    False
# 73    False
# 74    False
# 75    False
# Name: Major, Length: 76, dtype: bool

# %%
df[df["Major"] == "ECOLOGY"]
# Out:
#     Rank  Major_code    Major          Major_category  Total   Men  Women  \
# 71    72        3604  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#     ShareWomen  Median
# 71     0.57636   33000

# %%
df.loc[df["Major_code"] == 5000]
# Out:
#     Rank  Major_code              Major     Major_category  Total  Men  Women  \
# 45    46        5000  PHYSICAL SCIENCES  Physical Sciences   1436  894    542
#
#     ShareWomen  Median
# 45    0.377437   40000

# %%
df[df["ShareWomen"] > .9]
# Out:
#     Rank  Major_code                                          Major  \
# 40    41        6104                     MEDICAL ASSISTING SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
#
#    Major_category  Total   Men  Women  ShareWomen  Median
# 40         Health  11123   803  10320    0.927807   42000
# 74         Health  38279  1225  37054    0.967998   28000

# %%
df[(df["ShareWomen"] > 0.5) & (df["Major_category"] == "Health")]
# Out:
#     Rank  Major_code                                              Major  \
# 26    27        6107                                            NURSING
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 58    59        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# 65    66        6103         HEALTH AND MEDICAL ADMINISTRATIVE SERVICES
# 66    67        4002                                 NUTRITION SCIENCES
# 67    68        6110                        COMMUNITY AND PUBLIC HEALTH
# 69    70        6106            HEALTH AND MEDICAL PREPARATORY PROGRAMS
# 72    73        6109                      TREATMENT THERAPY PROFESSIONS
# 73    74        6100                GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102      COMMUNICATION DISORDERS SCIENCES AND SERVICES
#
# ...

# %%
df[(df["Major_category"] == "Health") | (df["Major_category"] == "Biology & Life Science")]
# Out:
#     Rank  Major_code                                              Major  \
# 26    27        6107                                            NURSING
# 35    36        3607                                       PHARMACOLOGY
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 42    43        4006                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 47    48        3605                                           GENETICS
# 48    49        3603                                  MOLECULAR BIOLOGY
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 51    52        3606                                       MICROBIOLOGY
# 53    54        3601                               BIOCHEMICAL SCIENCES
# 54    55        3602                                             BOTANY
# 58    59        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# ...

# %%
df[df["Major_category"].isin(["Health", "Biology"])]
# Out:
#     Rank  Major_code                                              Major  \
# 26    27        6107                                            NURSING
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 58    59        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# 65    66        6103         HEALTH AND MEDICAL ADMINISTRATIVE SERVICES
# 66    67        4002                                 NUTRITION SCIENCES
# 67    68        6110                        COMMUNITY AND PUBLIC HEALTH
# 69    70        6106            HEALTH AND MEDICAL PREPARATORY PROGRAMS
# 72    73        6109                      TREATMENT THERAPY PROFESSIONS
# 73    74        6100                GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102      COMMUNICATION DISORDERS SCIENCES AND SERVICES
#
# ...

# %%
df
# Out:
#     Rank  Major_code                                          Major  \
# 0      1        2419                          PETROLEUM ENGINEERING
# 1      2        2416                 MINING AND MINERAL ENGINEERING
# 2      3        2415                      METALLURGICAL ENGINEERING
# 3      4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                            NUCLEAR ENGINEERING
# ..   ...         ...                                            ...
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 0              Engineering   2339   2057    282    0.120564  110000
# ...

# %%
df[df["Major_category"].isin(["Engineering", "Health"])]
# Out:
#     Rank  Major_code                                              Major  \
# 0      1        2419                              PETROLEUM ENGINEERING
# 1      2        2416                     MINING AND MINERAL ENGINEERING
# 2      3        2415                          METALLURGICAL ENGINEERING
# 3      4        2417          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      5        2418                                NUCLEAR ENGINEERING
# 5      6        2405                               CHEMICAL ENGINEERING
# 7      8        2414                             MECHANICAL ENGINEERING
# 8      9        2401                              AEROSPACE ENGINEERING
# 9     10        2408                             ELECTRICAL ENGINEERING
# 10    11        2407                               COMPUTER ENGINEERING
# 11    12        5008                                  MATERIALS SCIENCE
# 12    13        2404                             BIOMEDICAL ENGINEERING
# ...

# %%
import pandas as pd
people_dict = {"first" : ["Richard", "Robert", "Jason"],
               "last" : ["Stone", "Deepdive", "Seaborn"],
               "email" : ["richardstone@email.com", "robertdeepdive@email.com", "jasonseaborn@email.com"]}
df = pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com

# %%
df.iloc[2, 1]
# Out:
# 'Seaborn'

# %%
df.iloc[1, 2]
# Out:
# 'robertdeepdive@email.com'

# %%
import numpy
outside = ["A1", "A1", "A1", "A2", "A2", "A2"]
inside = [1, 2, 3, 1, 2, 3]
hier_index = list(zip(outside, inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

np.random.seed(101)
data = pd.DataFrame(np.random.randn(6 ,2), index=hier_index, columns=["X", "Y"])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data.loc["A1"]
# Out:
#           X         Y
# 1  2.706850  0.628133
# 2  0.907969  0.503826
# 3  0.651118 -0.319318

# %%
data.loc["A1", "Y"]
# Out:
# 1    0.628133
# 2    0.503826
# 3   -0.319318
# Name: Y, dtype: float64

# %%
df["last"]
# Out:
# 0       Stone
# 1    Deepdive
# 2     Seaborn
# Name: last, dtype: object

# %%
df.last
# Out:
# <bound method NDFrame.last of      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2    Jason   Seaborn    jasonseaborn@email.com>

# %%
data = pd.DataFrame({
    "age" : [10, 22, 13, 21, 12, 11, 17],
    "section" : ["A", "B", "C", "B", "B", "A", "A"],
    "city" : ["Gurgaon", "Delhi", "Mumbai", "Delhi", "Mumbai", "Delhi", "Mumbai"],
    "gender" : ["M", "F", "F", "M", "M", "M", "F"],
    "favourite_color" : ["red", "blue", "yellow", "pink", "black", "green", "red"]
})
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data[["city", "age"]]
# Out:
#       city  age
# 0  Gurgaon   10
# 1    Delhi   22
# 2   Mumbai   13
# 3    Delhi   21
# 4   Mumbai   12
# 5    Delhi   11
# 6   Mumbai   17

# %%
data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %% [markdown]
# ### Data Frame Basics- 3

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("iris")
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns
df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
len(df) # satır sayısını veriyor sadece.
# Out:
# 150

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.mean()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_8636\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
df.sepal_length.sum()
# Out:
# 876.5

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.sepal_length.sum()
# Out:
# 876.5

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.sepal_length.unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.drop("species", axis=1).head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.drop([1, 3, 5]).head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4), columns=["A", "B", "C", "D"])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(["B", "C"], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
df = pd.read_csv("woman-stem.csv")
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  76 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df.describe()
# Out:
#             Rank   Major_code          Total            Men          Women  \
# count  76.000000    76.000000      76.000000      76.000000      76.000000
# mean   38.500000  3580.026316   25515.289474   12800.763158   12714.526316
# std    22.083176  1437.455038   43998.008553   21307.554101   29056.014723
# min     1.000000  1301.000000     609.000000     488.000000      77.000000
# 25%    19.750000  2409.750000    3782.000000    2047.750000    1227.500000
# 50%    38.500000  3601.500000   11047.500000    4583.000000    5217.500000
# 75%    57.250000  5002.250000   27509.250000   11686.500000   12463.500000
# max    76.000000  6199.000000  280709.000000  111762.000000  187621.000000
#
#        ShareWomen         Median
# count   76.000000      76.000000
# mean     0.436929   46118.421053
# std      0.232176   13187.223216
# min      0.077453   26000.000000
# 25%      0.247918   36150.000000
# 50%      0.405868   44350.000000
# 75%      0.591803   52250.000000
# ...

# %%
df["Major_code"].describe()
# Out:
# count      76.000000
# mean     3580.026316
# std      1437.455038
# min      1301.000000
# 25%      2409.750000
# 50%      3601.500000
# 75%      5002.250000
# max      6199.000000
# Name: Major_code, dtype: float64

# %%
df["Major_category"].value_counts()
# Out:
# Engineering                29
# Biology & Life Science     14
# Health                     12
# Computers & Mathematics    11
# Physical Sciences          10
# Name: Major_category, dtype: int64

# %%
df["Major_category"].value_counts(normalize=True)
# Out:
# Engineering                0.381579
# Biology & Life Science     0.184211
# Health                     0.157895
# Computers & Mathematics    0.144737
# Physical Sciences          0.131579
# Name: Major_category, dtype: float64

# %%
df.mean()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_8636\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Rank             38.500000
# Major_code     3580.026316
# Total         25515.289474
# Men           12800.763158
# Women         12714.526316
# ShareWomen        0.436929
# Median        46118.421053
# dtype: float64

# %%
df["ShareWomen"].mean()
# Out:
# 0.43692924057894733

# %%
df["ShareWomen"].loc[df["Major_category"] == "Engineering"].mean()
# Out:
# 0.23888867596551724

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df["Major_category"].unique()
# Out:
# array(['Engineering', 'Physical Sciences', 'Computers & Mathematics',
#        'Health', 'Biology & Life Science'], dtype=object)

# %%
unique_major_categories = df["Major_category"].unique().tolist()
unique_major_categories
# Out:
# ['Engineering',
#  'Physical Sciences',
#  'Computers & Mathematics',
#  'Health',
#  'Biology & Life Science']

# %%
df.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Major_category', 'Total', 'Men',
#        'Women', 'ShareWomen', 'Median'],
#       dtype='object')

# %%
import numpy as np
df.iloc[50:55]
# Out:
#     Rank  Major_code                                            Major  \
# 50    51        5003                                        CHEMISTRY
# 51    52        3606                                     MICROBIOLOGY
# 52    53        2106  COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY
# 53    54        3601                             BIOCHEMICAL SCIENCES
# 54    55        3602                                           BOTANY
#
#              Major_category  Total    Men  Women  ShareWomen  Median
# 50        Physical Sciences  66530  32923  33607    0.505141   39000
# 51   Biology & Life Science  15232   6383   8849    0.580948   38000
# 52  Computers & Mathematics   8066   6607   1459    0.180883   37500
# 53   Biology & Life Science  39107  18951  20156    0.515406   37400
# 54   Biology & Life Science   1329    626    703    0.528969   37000

# %%
df.iloc[50:55, 3]
# Out:
# 50          Physical Sciences
# 51     Biology & Life Science
# 52    Computers & Mathematics
# 53     Biology & Life Science
# 54     Biology & Life Science
# Name: Major_category, dtype: object

# %%
df.iloc[50:55, 2]
# Out:
# 50                                          CHEMISTRY
# 51                                       MICROBIOLOGY
# 52    COMPUTER ADMINISTRATION MANAGEMENT AND SECURITY
# 53                               BIOCHEMICAL SCIENCES
# 54                                             BOTANY
# Name: Major, dtype: object

# %%
df.iloc[50:55, 3] = np.NaN
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  71 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df.isnull()
# Out:
#      Rank  Major_code  Major  Major_category  Total    Men  Women  ShareWomen  \
# 0   False       False  False           False  False  False  False       False
# 1   False       False  False           False  False  False  False       False
# 2   False       False  False           False  False  False  False       False
# 3   False       False  False           False  False  False  False       False
# 4   False       False  False           False  False  False  False       False
# ..    ...         ...    ...             ...    ...    ...    ...         ...
# 71  False       False  False           False  False  False  False       False
# 72  False       False  False           False  False  False  False       False
# 73  False       False  False           False  False  False  False       False
# 74  False       False  False           False  False  False  False       False
# 75  False       False  False           False  False  False  False       False
#
#     Median
# 0    False
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Major_code        0
# Major             0
# Major_category    5
# Total             0
# Men               0
# Women             0
# ShareWomen        0
# Median            0
# dtype: int64

# %%
len(df)
# Out:
# 76

# %%
df.size
# Out:
# 684

# %%
df.shape
# Out:
# (76, 9)

# %% [markdown]
# ## Part 2

# %%
import seaborn as sns
import numpy as np
import pandas as pd
df = sns.load_dataset("planets")
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.groupby("method")["distance"].sum()
# Out:
# method
# Astrometry                           35.75
# Eclipse Timing Variations          1261.44
# Imaging                            2166.91
# Microlensing                      41440.00
# Orbital Brightness Modulation      2360.00
# Pulsar Timing                      1200.00
# Pulsation Timing Variations           0.00
# Radial Velocity                   27348.11
# Transit                          134242.77
# Transit Timing Variations          3313.00
# Name: distance, dtype: float64

# %%
df.groupby("method")[["distance"]].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Samsung\Desktop\Clarusway\Data Science Module 1\DawPy\pandas_preclass.ipynb Cell 153' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Samsung/Desktop/Clarusway/Data%20Science%20Module%201/DawPy/pandas_preclass.ipynb#ch0000152?line=0'>1</a> df.groupby("method")[["distance"]].sum()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7706, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    <a href='file:///c%3A/Users/Samsung/anaconda3/lib/site-packages/pandas/core/frame.py?line=7700'>7701</a> axis = self._get_axis_number(axis)
#    <a href='file:///c%3A/Users/Samsung/anaconda3/lib/site-packages/pandas/core/frame.py?line=7702'>7703</a> # https://github.com/python/mypy/issues/7642
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.pivot_table(values="age", index="sex", columns="class")
# Out:
# class       First     Second      Third
# sex
# female  34.611765  28.722973  21.750000
# male    41.281386  30.740707  26.507589

# %%
df = pd.read_csv("weather.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index="date", columns="city")
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
df.pivot(index="date", columns="city", values="humidity")
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %%
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index="city", columns="date")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index="city", columns="date", aggfunc="sum")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai        163      111         153      162
# new york      110      122         126      142

# %%
df.pivot_table(index="city", columns="date", aggfunc="mean")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
df.pivot_table(index="city", columns="date", aggfunc="mean", margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %%
df = pd.read_csv("weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
type(df["date"][0])
# Out:
# str

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
type(df["date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
df.pivot_table(index=pd.Grouper(freq="M", key="date"), columns="city")
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %%
data = {"A" : ["foo", "foo", "foo", "bar", "bar", "bar"],
        "B" : ["one", "one", "two", "two", "one", "one"],
        "C" : ["x", "y", "x", "y", "x", "y"],
        "D" : [1, 3, 2, 5, 4, 1]}
df = pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean")
# Out:
#              D
# A   B   C
# bar one x  4.0
#         y  1.0
#     two y  5.0
# foo one x  1.0
#         y  3.0
#     two x  2.0

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean").stack()
# Out:
# A    B    C
# bar  one  x  D    4.0
#           y  D    1.0
#      two  y  D    5.0
# foo  one  x  D    1.0
#           y  D    3.0
#      two  x  D    2.0
# dtype: float64

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean")
# Out:
#              D
# A   B   C
# bar one x  4.0
#         y  1.0
#     two y  5.0
# foo one x  1.0
#         y  3.0
#     two x  2.0

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean").unstack()
# Out:
#            D
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean").unstack().unstack()
# Out:
#        D
# C      x         y
# B    one  two  one  two
# A
# bar  4.0  NaN  1.0  5.0
# foo  1.0  2.0  3.0  NaN

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean").unstack().unstack().unstack()
# Out:
#    C  B    A
# D  x  one  bar    4.0
#            foo    1.0
#       two  bar    NaN
#            foo    2.0
#    y  one  bar    1.0
#            foo    3.0
#       two  bar    5.0
#            foo    NaN
# dtype: float64

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean").stack()
# Out:
# A    B    C
# bar  one  x  D    4.0
#           y  D    1.0
#      two  y  D    5.0
# foo  one  x  D    1.0
#           y  D    3.0
#      two  x  D    2.0
# dtype: float64

# %%
df.groupby(["A", "B", "C"])[["D"]].aggregate("mean").unstack()
# Out:
#            D
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN

# %%
import pandas as pd
df = pd.read_excel("stocks.xlsx", header=[0, 1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack()
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
df.stack(level=0)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...

# %%
df_stacked = df.stack()
df_stacked.head()
# Out:
#              Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company      NaN                            NaN         2017-06-05
#   Facebook   155.0                          37.10                NaT
#   Google     955.0                          32.00                NaT
#   Microsoft   66.0                          30.31                NaT
# 1 Company      NaN                            NaN         2017-06-06

# %%
df_stacked.unstack()
# Out:
#     Price                            Price to earnings ratio (P/E)           \
#   Company Facebook  Google Microsoft                       Company Facebook
# 0     NaN    155.0   955.0      66.0                           NaN    37.10
# 1     NaN    150.0   987.0      69.0                           NaN    36.98
# 2     NaN    153.0   963.0      62.0                           NaN    36.78
# 3     NaN    155.0  1000.0      61.0                           NaN    36.11
# 4     NaN    156.0  1012.0      66.0                           NaN    37.07
#
#                    Unnamed: 0_level_0
#   Google Microsoft            Company Facebook Google Microsoft
# 0   32.0     30.31         2017-06-05      NaT    NaT       NaT
# 1   31.3     30.56         2017-06-06      NaT    NaT       NaT
# 2   31.7     30.46         2017-06-07      NaT    NaT       NaT
# 3   31.2     30.11         2017-06-08      NaT    NaT       NaT
# 4   30.0     31.00         2017-06-09      NaT    NaT       NaT
