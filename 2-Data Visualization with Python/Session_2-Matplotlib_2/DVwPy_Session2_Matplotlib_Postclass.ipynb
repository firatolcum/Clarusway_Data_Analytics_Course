# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1
sns.set_style(style="darkgrid")

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['A', 'B', 'C','D', 'E', 'F', 'G']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#    income  expense
# A     100       30
# B      80      100
# C     150      100
# D      48       20
# E      52       75

# %%
sns.barplot(data=df)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(6,4))
p = np.arange(len(index))
width = 0.3
ax.bar(p - width/2, income, width=width, label="income")
ax.bar(p + width/2, expense, width=width, label="expense")
ax.set_xticks(p)
ax.set_xticklabels(index)
plt.legend()
plt.show()

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['A', 'B', 'C','D', 'E', 'F', 'G']

df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()

fig, ax = plt.subplots()

sns.barplot(x=index, y=[income,expense], label="income")
sns.barplot(x=index, y=expense, label="expense")

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [261], in <cell line: 10>()
#       6 df.head()
#       8 fig, ax = plt.subplots()
# ---> 10 sns.barplot(x=index, y=[income,expense], label="income")
#      11 sns.barplot(x=index, y=expense, label="expense")
#      13 plt.legend()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['A', 'B', 'C','D', 'E', 'F', 'G']

df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()

fig, ax = plt.subplots()

ax.bar(index,income, label="income")
ax.bar(index, expense, label="expense", bottom=True)

plt.legend()
plt.show()

# %%
ax = sns.barplot(x=index, y=income, data=df, hue=income)
sns.barplot(data=df, x=index, y=income, hue=expense)
# Out:
# <AxesSubplot:>

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')

# %%
sns.barplot(x=df.index, y=df.income, color="b",label="income")
sns.barplot(x=df.index, y=df.expense, label="expense")

plt.legend()
plt.show()

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 6
sns.histplot(data=tips["total_bill"],bins=10, alpha=1)
plt.xlabel("")
plt.ylabel("Frequency")
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["tip"].mean()
# Out:
# 2.9982786885245902

# %%
# 7
tips_avg = sns.lineplot(data=tips, x="size", y="tip", ci=None)
tips_avg.set_ylabel("");

# %%
plt.plot(data=tips, x="size", y="tip")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [163], in <cell line: 1>()
# ----> 1 plt.plot(data=tips, x="size", y="tip")
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
# 8
tips_avg =sns.lineplot(x=tips["size"], y=tips["tip"],linestyle="--", ci=None)
tips_avg.set_ylabel("");

# %%
#9
sns.scatterplot(x=tips["tip"], y=tips["total_bill"]);

# %%
sns.scatterplot(x=tips["tip"], y=tips["total_bill"]);

# %%
sns.scatterplot(data=tips, x="tip", y="total_bill", hue="size",palette="RdBu");

# %%
ax = sns.scatterplot(data=tips,x="tip", y="total_bill", hue="size", palette='RdBu')

norm = plt.Normalize(tips['size'].min(), tips['size'].max())
sm = plt.cm.ScalarMappable(cmap="RdBu", norm=norm)
sm.set_array([])

# Remove the legend and add a colorbar
ax.get_legend().remove()
ax.figure.colorbar(sm)

plt.show()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_2732\1575015019.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   ax.figure.colorbar(sm)

# %%
ax = sns.scatterplot(data=tips,x="tip", y="total_bill", hue="size", palette='RdBu')

norm = plt.Normalize(tips['size'].min(), tips['size'].max())
sm = plt.cm.ScalarMappable(cmap="RdBu", norm=norm)


# Remove the legend and add a colorbar
ax.get_legend().remove()
ax.figure.colorbar(sm)
plt.show()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_2732\1052978467.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   ax.figure.colorbar(sm)

# %%
#11
sns.boxplot(x=tips["size"], y=tips["total_bill"]);

# %%
12

# %%
x = np.arange(0, 30, 0.2)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
from matplotlib import style
style.use("dark_background")

x = np.arange(0, 30, 0.2)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
from matplotlib import style
style.use("fivethirtyeight")

x = np.arange(0, 30, 0.2)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
from matplotlib import style
style.use("classic")

x = np.arange(0, 30, 0.2)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
from matplotlib import style
style.use("grayscale")

x = np.arange(0, 30, 0.2)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
style.use("default")

x = np.arange(0, 30, 0.2)
y1 = np.sin(x)
y2 = np.cos(x)

plt.suptitle("Super title", fontsize=30)
plt.title("sine Function")
plt.grid(True)
plt.plot(x, y1, label="Sine")
plt.plot(x, y2, label="Cosine")
plt.xlabel("Number of students")
plt.ylabel("Height of students")

         
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %%
style.use("default")

x = np.arange(0, 30, 0.2)
y1 = np.sin(x)
y2 = np.cos(x)

plt.suptitle("Super title", fontsize=30)
plt.title("sine Function")
plt.grid(True)
plt.plot(x, y1, label="Sine")
plt.plot(x, y2, label="Cosine")
plt.xlabel("Number of students")
plt.ylabel("Height of students")

         
plt.legend(loc="lower left")
plt.tight_layout()
plt.show()

# %%
x = np.linspace(0, 5, 8)
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(x, x+13, color="green", ls="-", marker="o", markersize=10)

# %%
company = ["GOOGL", "AMZN", "MSFT", "FB"]
revenue = [90, 136, 89, 27]
xpos = np.arange(len(company))
profit = [40, 2, 34, 12]

# %%
plt.xticks(xpos,company)
plt.bar(xpos, revenue)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.xticks(xpos, company)

plt.ylabel("revenue")
plt.xlabel("US Tech Stocks")

plt.bar(ypos, revenue, label="Revenue")
plt.bar(ypos, profit, label="Profit")

plt.legend()
plt.show()

# %%
plt.xticks(xpos, company)

plt.ylabel("revenue")
plt.xlabel("US Tech Stocks")

plt.bar(ypos-0.2, revenue, label="Revenue")
plt.bar(ypos+0.2, profit, label="Profit")

plt.legend()
plt.show()

# %%
plt.xticks(xpos, company)

plt.ylabel("revenue")
plt.xlabel("US Tech Stocks")

plt.bar(ypos-0.2, revenue, label="Revenue", width= 0.4)
plt.bar(ypos+0.2, profit, label="Profit", width=0.4)

plt.title("US Tech Stocks")
plt.legend()
plt.show()

# %%
plt.yticks(xpos, company)



plt.barh(ypos-0.2, revenue, label="Revenue")
plt.barh(ypos+0.2, profit, label="Profit")

plt.title("US Tech Stocks")
plt.legend()
plt.show()

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar)
plt.show()

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color="g", histtype="step")
plt.show()

# %%
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.95, color="g")
plt.show()

# %%
blood_sugar_man = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
len(blood_sugar_man) == len(blood_sugar_women)
# Out:
# True

# %%
plt.xlabel("sugr range")
plt.ylabel("total number of patients")
plt.title("blood sugar analysis")

plt.hist([blood_sugar_man, blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=["green", "orange"], label=["men", "women"])
plt.legend()
plt.show()

# %%
plt.xlabel("sugr range")
plt.ylabel("total number of patients")
plt.title("blood sugar analysis")

plt.hist([blood_sugar_man, blood_sugar_women], bins=[80,100,125,150], rwidth=0.95, color=["green", "orange"],
         label=["men", "women"], orientation="horizontal")
plt.legend()
plt.show()

# %%
exp_vals = [1400, 600, 300, 410, 250]
exp_labels = ["Home Rent", "Food", "Phone/Internet Bill", "Car", "Other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels)
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5)
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5, autopct="%0.3f%%")
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5, autopct="%0.2f%%")
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5, autopct="%0.0f%%", shadow=True)
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5, autopct="%0.1f%%", explode=[0,0.1,0,0.1,0])
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5, autopct="%0.1f%%", explode=[0,0.1,0,0.1,0], startangle=45)
plt.show()

# %%
plt.axis("equal")
plt.pie(exp_vals, labels=exp_labels, radius=1.5, autopct="%0.1f%%", explode=[0,0.1,0,0.1,0], startangle=90)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.plot(age, salary)
plt.xlabel("age")
plt.ylabel("salary")
plt.title("Salary by Age")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(age, salary, "r")
ax.set_xlabel("age")
ax.set_ylabel("salary")
ax.set_title("Salary by Age")


plt.show()

# %%
plt.plot(age, salary, "r", age, salary_2, "g")



plt.show()

# %%
plt.figure(figsize=(15,3))

plt.subplot(121)
plt.plot(age, salary, "c")
plt.title("Age by Salary 1")
plt.xlabel("age")
plt.ylabel("salary")

plt.subplot(122)
plt.plot(age, salary_2, "r")
plt.title("Age by Salary 2")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.show()

# %%
plt.figure(figsize=(15,3))

plt.subplot(121)
plt.plot(age, salary, "r+", ls="--")
plt.title("Age by Salary 1")
plt.xlabel("age")
plt.ylabel("salary")

plt.subplot(122)
plt.plot(age, salary_2, "bo", linestyle="-")
plt.title("Age by Salary 2")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

ax[0].plot(age, salary)
ax[0].set_xlabel("age")
ax[0].set_ylabel("salary")
ax[0].set_title("age and salary 1")

ax[1].plot(age, salary_2, color="red")
ax[1].set_xlabel("age")
ax[1].set_ylabel("salary")
ax[1].set_title("age and salary 2")


plt.tight_layout()
plt.show()

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.title(f"Subplot: {i}")
    plt.text(0.5, 0.5, i, fontsize=18, ha="center")
    
plt.suptitle("This is Functional Method")
plt.tight_layout()
plt.show()

# %%
age = np.array([15, 17, 18, 17, 12, 17, 12, 19, 14, 11, 12, 19, 16, 13])
weight = np.array([99, 86, 87, 88, 81, 86, 93, 87, 94, 78, 77, 85, 86, 85])

plt.scatter(age, weight)
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(10,8))

plt.scatter(x="total_bill", y="tip", data=tips)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))


ax.scatter(x="total_bill", y="tip", data=tips, color="r")
ax.set_xlabel("Total Bill")
ax.set_ylabel("Tip")
ax.set_title("Total Bill and Tip")


plt.show()

# %%
sports = ["Football", "Volleyball", "Basketball", "Hentboll", "Pinball"]
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
ax[0].bar(x=sports, height=students, color=["red", "blue", "green", "pink", "yellow"])
ax[1].bar(langs, students)


plt.show()

# %%
sports = ["Football", "Volleyball", "Basketball", "Hentboll", "Pinball"]
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10, 6))
ax[0].barh(sports, students, color=["red", "blue", "green", "pink", "yellow"])
ax[1].barh(langs, students)



plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("day",as_index=False).sum()
# Out:
#     day  total_bill     tip  size
# 0  Thur     1096.33  171.83   152
# 1   Fri      325.88   51.96    40
# 2   Sat     1778.40  260.40   219
# 3   Sun     1627.16  247.39   216

# %%
tips.groupby("day",as_index=False)["total_bill"].sum()
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
days = list(tips.day.unique())
days
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']

# %%
day_of_total_bill = list(tips.groupby("day")["total_bill"].sum())
day_of_total_bill
# Out:
# [1096.33, 325.88, 1778.4, 1627.16]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(days, day_of_total_bill)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(days, day_of_total_bill, color="red")

plt.show()

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
tips.groupby("day")["tip"].sum().values
# Out:
# array([171.83,  51.96, 260.4 , 247.39])

# %%
tips.groupby("day")["tip"].sum().index
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category', name='day')

# %%
days = list(tips.groupby("day")["tip"].sum().index)
days
# Out:
# ['Thur', 'Fri', 'Sat', 'Sun']

# %%
day_of_total_bill
# Out:
# [1096.33, 325.88, 1778.4, 1627.16]

# %%
total_tip_of_day = list(tips.groupby("day")["tip"].sum().values)
total_tip_of_day
# Out:
# [171.82999999999998, 51.96, 260.4, 247.39]

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.bar(days, day_of_total_bill)
ax.bar(days, total_tip_of_day, bottom=day_of_total_bill)

plt.show()

# %%
days
# Out:
# ['Thur', 'Fri', 'Sat', 'Sun']

# %%
p = np.arange(len(days))
p
# Out:
# array([0, 1, 2, 3])

# %%
fig, ax = plt.subplots(figsize=(10, 5))

p = np.arange(len(days))

width = 0.20

ax.bar(p - width/2, day_of_total_bill, width, label="total_bill")
ax.bar(p + width/2, total_tip_of_day,width, label="tip")

ax.set_xticks(p)
ax.set_xticklabels(days)
plt.legend()
plt.show()

# %%
x = np.random.randn(250)
plt.hist(x=x, bins=20)
plt.show()

# %%
plt.hist(tips["total_bill"]);

# %%
plt.hist(tips["tip"]);

# %%
x = np.random.normal(170, 10, 250)

# %%
plt.boxplot(x);

# %%
plt.boxplot(x,vert=False);

# %%
box = np.array(np.random.rand(10,4))
box
# Out:
# array([[0.62297077, 0.5158069 , 0.94610543, 0.36790601],
#        [0.14628445, 0.70456978, 0.15319861, 0.33009186],
#        [0.62792857, 0.6143824 , 0.31505919, 0.09608425],
#        [0.87968079, 0.54578151, 0.72376577, 0.51733733],
#        [0.15064222, 0.96040923, 0.48209749, 0.89492464],
#        [0.91324992, 0.8312501 , 0.16820275, 0.68229911],
#        [0.52685369, 0.99075075, 0.23989663, 0.36971541],
#        [0.32866408, 0.78724473, 0.83997938, 0.50077375],
#        [0.92475116, 0.66410054, 0.54887234, 0.1951057 ],
#        [0.76632154, 0.76474593, 0.23362441, 0.02233861]])

# %%
plt.boxplot(box,labels=["A", "B", "C", "D"]);

# %%
plt.boxplot(tips["tip"], vert=False, notch=True);

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.figure(figsize=(10, 8))
y = np.array([35, 25 ,25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(x=y,labels=mylabels, labeldistance=0.7, autopct="%.f%%");

# %%
plt.figure(figsize=(10, 8))
y = np.array([35, 25 ,25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(x=y,labels=mylabels, labeldistance=1.1, autopct="%.f%%");

# %%
y = np.array([35, 25 ,25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.figure(figsize=(10, 8))

plt.pie(x=y,labels=mylabels, labeldistance=None, explode=[0.05, 0, 0, 0], autopct="%.f%%")

plt.legend();

# %%
y = np.array([25, 35, 25, 15])
my_labels = ["Bananas", "Apples", "Cherrries", "Dates"]

plt.pie(x=y, radius=2,
        labels=my_labels,
       labeldistance=0.7,
       autopct="%.1f%%",
       startangle=90,
       shadow=True,
       pctdistance= 1.1,
       colors = ["gold", "yellowgreen", "lightcoral", "lightskyblue", "lightgreen", "pink"],
       explode=[0, 0, 0.1, 0.1])
plt.legend(loc=(1.5, 1))

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.plot()
# Out:
# <AxesSubplot:>

# %%
tips.iloc[:, 0:2].plot()
# Out:
# <AxesSubplot:>

# %%
tips.plot(x="tip", y="total_bill", kind="scatter");

# %%
tips.plot(x="tip", y="total_bill", kind="kde");

# %%
np.random.randint(100, size=(5, 4))
# Out:
# array([[21, 15, 37, 43],
#        [83, 34, 76, 61],
#        [48, 17, 33, 92],
#        [19, 89, 93, 38],
#        [97, 85,  3, 79]])

# %%
df = pd.DataFrame(np.random.randint(100, size=(5, 4)),
                 columns=["a", "b", "c", "d"])
df
# Out:
#     a   b   c   d
# 0  79  27  49  61
# 1  97  95  48  91
# 2  45  52  79  55
# 3   1  75   9  77
# 4  52  53  44  91

# %%
df.plot.bar();

# %%
df.plot.bar()
plt.legend(loc=(1.1, 0.7));

# %%
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("day")["tip"].sum()
# Out:
# day
# Thur    171.83
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Name: tip, dtype: float64

# %%
tips.groupby("day")["tip"].sum().plot.bar(x="day", y="tip")
# Out:
# <AxesSubplot:xlabel='day'>

# %%
tips.groupby("sex")["tip"].sum().plot.bar(x="sex", y="tip")
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
tips.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips[["tip", "total_bill", "size"]].hist()
plt.tight_layout()
plt.show()

# %%
tips[["tip", "total_bill", "size"]].diff().plot.hist()
plt.tight_layout()
plt.show()

# %%
tips[["tip", "total_bill", "size"]].diff().hist()
plt.tight_layout()
plt.show()

# %%
tips.plot.box();

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
tips.groupby("day").sum().plot.pie(subplots=True, figsize=(18, 5), autopct="%.2f", labeldistance=0.8)
plt.legend()
plt.show()

# %%
df_kde = pd.Series(np.random.randn(1000))
df_kde
# Out:
# 0     -0.789083
# 1      2.115334
# 2      0.691270
# 3      0.228879
# 4     -0.984880
#          ...
# 995   -0.756100
# 996    0.043811
# 997   -1.324959
# 998   -0.345253
# 999    0.254827
# Length: 1000, dtype: float64

# %%
df_kde.plot.kde();

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.groupby("day")[["size", "tip"]].sum()
# Out:
#       size     tip
# day
# Thur   152  171.83
# Fri     40   51.96
# Sat    219  260.40
# Sun    216  247.39

# %%
tips.groupby("day")[["size", "tip"]].sum().plot.kde();

# %% [markdown]
# ### Dimensional Plots

# %%
# The 3d plots are enabled by importing the mplot3d toolkit.
from mpl_toolkits import mplot3d

fig = plt.figure(figsize=(12, 8))
ax = plt.axes(projection="3d")

# %%
# Data for a three- dimensional line

# %%
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
 
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection= "3d")

# %%
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
 
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection= "3d")

ax.plot3D(xline, yline, zline)

# %%
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
 
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection= "3d")

ax.plot3D(xline, yline, zline, "red");

# %%
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection ="3d")

ax.scatter3D(xdata, ydata, zdata)

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection ="3d")

ax.scatter3D(xdata, ydata, zdata,c=zdata, cmap="Reds")

# %% [markdown]
# ### Pre-class Extra Links

# %%
# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = x**2

# %%
len(x)
# Out:
# 400

# %%
len(y)
# Out:
# 400

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('A single plot');

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(x, y)
ax[1].plot(x, -y);

plt.suptitle("Vertically stacked subplots");

# %%
fig, ax = plt.subplots(1, 2)
ax[0].plot(x, y, "r")
ax[1].plot(-x, y, "b")

# %%
fig, ax = plt.subplots(2, 2)

ax[0,0].plot(x, y, "r")
ax[0,1].plot(-x, y, "g")
ax[1,0].plot(x, -y, "y")
ax[1,1].plot(-x, -y, "b")

ax[0,0].set_title("Red and First")
ax[0,1].set_title("Green and Second")
ax[1,0].set_title("Yellow and Third")
ax[1,1].set_title("Blue and Fourth")

for ax in ax.flat:
    ax.set(xlabel="x-label", ylabel= "y-label")


plt.suptitle("Fantasy")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2, sharex=True)

ax[0,0].plot(x, y, "r")
ax[0,1].plot(-x, y, "g")
ax[1,0].plot(x, -y, "y")
ax[1,1].plot(-x, -y, "b")

ax[0,0].set_title("Red and First")
ax[0,1].set_title("Green and Second")
ax[1,0].set_title("Yellow and Third")
ax[1,1].set_title("Blue and Fourth")

for ax in ax.flat:
    ax.set(xlabel="x-label", ylabel= "y-label")


plt.suptitle("Fantasy")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2, subplot_kw=dict(projection = "polar"))

ax[0,0].plot(x, y, "r")
ax[0,1].plot(-x, y, "g")
ax[1,0].plot(x, -y, "y")
ax[1,1].plot(-x, -y, "b")

ax[0,0].set_title("Red and First")
ax[0,1].set_title("Green and Second")
ax[1,0].set_title("Yellow and Third")
ax[1,1].set_title("Blue and Fourth")

for ax in ax.flat:
    ax.set(xlabel="x-label", ylabel= "y-label")


plt.suptitle("Fantasy")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(2, 2, subplot_kw={"projection": "polar"})

ax[0,0].plot(x, y, "r")
ax[0,1].plot(-x, y, "g")
ax[1,0].plot(x, -y, "y")
ax[1,1].plot(-x, -y, "b")


for ax in ax.flat:
    ax.set(xlabel="x-label", ylabel= "y-label")

plt.figure(figsize=(15, 20))
plt.suptitle("Fantasy")
plt.tight_layout()
plt.show()

# %%
#If you wish to update the default parameters of the matplotlib function, 
#then you need to use plt.rcParams.update() the function available in matplotlib.

plt.rcParams.update()

# %%
plt.rcParamsDefault
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': False,
# ...
